# %% [markdown]
# <a href="https://colab.research.google.com/github/garfield-gray/Optimization/blob/main/NonConvex/Cutting_Plane_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Warm up

# %%
# watch inheritance in python to improve your coding

# %%
import numpy as np

# %% [markdown]
# # The Code
